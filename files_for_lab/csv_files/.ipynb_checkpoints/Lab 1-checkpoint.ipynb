# %%
import pandas as pd

# %%
data1 = pd.read_csv("file1.csv")

# %%
data1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data2 = pd.read_csv('file2.csv')

# %%
data1.columns
# Out:
# Index(['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value',
#        'Income', 'Monthly Premium Auto', 'Number of Open Complaints',
#        'Policy Type', 'Vehicle Class', 'Total Claim Amount'],
#       dtype='object')

# %%
data1.columns = data1.columns.str.upper()

# %%
data1.columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'EDUCATION', 'CUSTOMER LIFETIME VALUE',
#        'INCOME', 'MONTHLY PREMIUM AUTO', 'NUMBER OF OPEN COMPLAINTS',
#        'POLICY TYPE', 'VEHICLE CLASS', 'TOTAL CLAIM AMOUNT'],
#       dtype='object')

# %%
data1.columns = data1.columns.str.replace(' ', '_')

# %%
data1.columns
# Out:
# Index(['CUSTOMER', 'ST', 'GENDER', 'EDUCATION', 'CUSTOMER_LIFETIME_VALUE',
#        'INCOME', 'MONTHLY_PREMIUM_AUTO', 'NUMBER_OF_OPEN_COMPLAINTS',
#        'POLICY_TYPE', 'VEHICLE_CLASS', 'TOTAL_CLAIM_AMOUNT'],
#       dtype='object')

# %% [markdown]
# data1.columns = data1.columns.str.title()

# %%
data1.columns = data1.columns.str.title()

# %%
data1.columns
# Out:
# Index(['Customer', 'St', 'Gender', 'Education', 'Customer_Lifetime_Value',
#        'Income', 'Monthly_Premium_Auto', 'Number_Of_Open_Complaints',
#        'Policy_Type', 'Vehicle_Class', 'Total_Claim_Amount'],
#       dtype='object')

# %%
data1
# Out:
#      Customer          St Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer_Lifetime_Value   Income  Monthly_Premium_Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data2.columns = data2.columns.str.title().str.replace(' ','_')

# %%
data2
# Out:
#     Customer          St Gender Education Customer_Lifetime_Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly_Premium_Auto Number_Of_Open_Complaints  Total_Claim_Amount  \
# ...

# %%
data3 = pd.read_csv('file3.csv')

# %%
data3.columns = data3.columns.str.title().str.replace(' ','_')

# %%
data3
# Out:
#      Customer       State  Customer_Lifetime_Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly_Premium_Auto  Number_Of_Open_Complaints  \
# ...

# %%
data1
# Out:
#      Customer          St Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer_Lifetime_Value   Income  Monthly_Premium_Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data2
# Out:
#     Customer          St Gender Education Customer_Lifetime_Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly_Premium_Auto Number_Of_Open_Complaints  Total_Claim_Amount  \
# ...

# %%
data1.columns
# Out:
# Index(['Customer', 'St', 'Gender', 'Education', 'Customer_Lifetime_Value',
#        'Income', 'Monthly_Premium_Auto', 'Number_Of_Open_Complaints',
#        'Policy_Type', 'Vehicle_Class', 'Total_Claim_Amount'],
#       dtype='object')

# %%
data2.columns
# Out:
# Index(['Customer', 'St', 'Gender', 'Education', 'Customer_Lifetime_Value',
#        'Income', 'Monthly_Premium_Auto', 'Number_Of_Open_Complaints',
#        'Total_Claim_Amount', 'Policy_Type', 'Vehicle_Class'],
#       dtype='object')

# %%
data3.columns
# Out:
# Index(['Customer', 'State', 'Customer_Lifetime_Value', 'Education', 'Gender',
#        'Income', 'Monthly_Premium_Auto', 'Number_Of_Open_Complaints',
#        'Policy_Type', 'Total_Claim_Amount', 'Vehicle_Class'],
#       dtype='object')

# %%
#df = df.reindex(columns=['Name', 'Gender', 'Age', 'City', 'Education'])
#print(df)

#data3 = data3.reindex(columns = ['Customer', 'St', 'Gender', 'Education', 'Customer_Lifetime_Value',
     #  'Income', 'Monthly_Premium_Auto', 'Number_Of_Open_Complaints',
      # 'Total_Claim_Amount', 'Policy_Type', 'Vehicle_Class'])

# %%
data3
# Out:
#      Customer       State  Customer_Lifetime_Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly_Premium_Auto  Number_Of_Open_Complaints  \
# ...

# %%
data1 = data1.rename(columns = {'St':'State'})
data1
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer_Lifetime_Value   Income  Monthly_Premium_Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data2 = data2.rename(columns = {'St':'State'})
data2
# Out:
#     Customer       State Gender Education Customer_Lifetime_Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly_Premium_Auto Number_Of_Open_Complaints  Total_Claim_Amount  \
# ...

# %%
data3
# Out:
#      Customer       State  Customer_Lifetime_Value             Education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      Gender  Income  Monthly_Premium_Auto  Number_Of_Open_Complaints  \
# ...

# %%
columns1 = data1.columns
columns2 = data2.columns
columns3 = data3.columns
print(columns1)
print(columns2)
print(columns3)
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer_Lifetime_Value',
#        'Income', 'Monthly_Premium_Auto', 'Number_Of_Open_Complaints',
#        'Policy_Type', 'Vehicle_Class', 'Total_Claim_Amount'],
#       dtype='object')
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer_Lifetime_Value',
#        'Income', 'Monthly_Premium_Auto', 'Number_Of_Open_Complaints',
#        'Total_Claim_Amount', 'Policy_Type', 'Vehicle_Class'],
#       dtype='object')
# Index(['Customer', 'State', 'Customer_Lifetime_Value', 'Education', 'Gender',
#        'Income', 'Monthly_Premium_Auto', 'Number_Of_Open_Complaints',
#        'Policy_Type', 'Total_Claim_Amount', 'Vehicle_Class'],
#       dtype='object')

# %%
column_names3 = ['Customer', 'State', 'Gender', 'Education', 'Customer_Lifetime_Value',
       'Income', 'Monthly_Premium_Auto', 'Number_Of_Open_Complaints',
       'Policy_Type', 'Total_Claim_Amount', 'Vehicle_Class']
data3 = data3.reindex(columns = column_names3)
data3
# Out:
#      Customer       State Gender             Education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       Customer_Lifetime_Value  Income  Monthly_Premium_Auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
len(columns1)
# Out:
# 11

# %%
len(columns2)
# Out:
# 11

# %%
len(columns3)
# Out:
# 11

# %%
column_names = columns1
column_names
# Out:
# Index(['Customer', 'State', 'Gender', 'Education', 'Customer_Lifetime_Value',
#        'Income', 'Monthly_Premium_Auto', 'Number_Of_Open_Complaints',
#        'Policy_Type', 'Vehicle_Class', 'Total_Claim_Amount'],
#       dtype='object')

# %%
data2 = data2.reindex(columns = column_names)
data3 = data3.reindex(columns = column_names)
data2
# Out:
#     Customer       State Gender Education Customer_Lifetime_Value  Income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      Monthly_Premium_Auto Number_Of_Open_Complaints     Policy_Type  \
# ...

# %%
data3
# Out:
#      Customer       State Gender             Education  \
# 0     SA25987  Washington      M  High School or Below
# 1     TB86706     Arizona      M                Master
# 2     ZL73902      Nevada      F              Bachelor
# 3     KX23516  California      F  High School or Below
# 4     FN77294  California      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#       Customer_Lifetime_Value  Income  Monthly_Premium_Auto  \
# 0                 3479.137523       0                   104
# 1                 2502.637401       0                    66
# 2                 3265.156348   25820                    82
# ...

# %%
data = pd.concat([data1, data2, data3], axis = 0)
data
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer_Lifetime_Value   Income  Monthly_Premium_Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
data.dtypes
# Out:
# Customer                      object
# State                         object
# Gender                        object
# Education                     object
# Customer_Lifetime_Value       object
# Income                       float64
# Monthly_Premium_Auto         float64
# Number_Of_Open_Complaints     object
# Policy_Type                   object
# Vehicle_Class                 object
# Total_Claim_Amount           float64
# dtype: object

# %%
numerical = ['int', 'float']
numerical_columns = data.select_dtypes(include = numerical)
numerical_columns
# Out:
#        Income  Monthly_Premium_Auto  Total_Claim_Amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
columns = data.columns
num_columns = data._get_numeric_data().columns
num_columns
# Out:
# Index(['Income', 'Monthly_Premium_Auto', 'Total_Claim_Amount'], dtype='object')

# %%
categ_columns = list(set(columns)-set(num_columns))
categ_columns
# Out:
# ['State',
#  'Number_Of_Open_Complaints',
#  'Gender',
#  'Vehicle_Class',
#  'Education',
#  'Customer',
#  'Policy_Type',
#  'Customer_Lifetime_Value']

# %%
categorical_columns = data[categ_columns]
categorical_columns
# Out:
#            State Number_Of_Open_Complaints Gender  Vehicle_Class  \
# 0     Washington                    1/0/00    NaN  Four-Door Car
# 1        Arizona                    1/0/00      F  Four-Door Car
# 2         Nevada                    1/0/00      F   Two-Door Car
# 3     California                    1/0/00      M            SUV
# 4     Washington                    1/0/00      M  Four-Door Car
# ...          ...                       ...    ...            ...
# 7065  California                         0      M  Four-Door Car
# 7066  California                         0      F  Four-Door Car
# 7067  California                         3      M  Four-Door Car
# 7068  California                         0      M  Four-Door Car
# 7069  California                         0      M   Two-Door Car
#
#                  Education Customer     Policy_Type Customer_Lifetime_Value
# 0                   Master  RB50392   Personal Auto                     NaN
# ...

# %%
data.isna().sum()
# Out:
# Customer                     2937
# State                        2937
# Gender                       3059
# Education                    2937
# Customer_Lifetime_Value      2944
# Income                       2937
# Monthly_Premium_Auto         2937
# Number_Of_Open_Complaints    2937
# Policy_Type                  2937
# Vehicle_Class                2937
# Total_Claim_Amount           2937
# dtype: int64

# %%
numerical_columns
# Out:
#        Income  Monthly_Premium_Auto  Total_Claim_Amount
# 0         0.0                1000.0            2.704934
# 1         0.0                  94.0         1131.464935
# 2     48767.0                 108.0          566.472247
# 3         0.0                 106.0          529.881344
# 4     36357.0                  68.0           17.269323
# ...       ...                   ...                 ...
# 7065  71941.0                  73.0          198.234764
# 7066  21604.0                  79.0          379.200000
# 7067      0.0                  85.0          790.784983
# 7068  21941.0                  96.0          691.200000
# 7069      0.0                  77.0          369.600000
#
# [12074 rows x 3 columns]

# %%
round(data['Income'].mean(), 2)
# Out:
# 37828.82

# %%
data = data.drop(['Education', 'Number_Of_Open_Complaints'], axis = 1)
data
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Customer_Lifetime_Value', 'Income',
#        'Monthly_Premium_Auto', 'Policy_Type', 'Vehicle_Class',
#        'Total_Claim_Amount'],
#       dtype='object')

# %%
data['Customer_Lifetime_Value']
# Out:
# 0               NaN
# 1        697953.59%
# 2       1288743.17%
# 3        764586.18%
# 4        536307.65%
#            ...
# 7065    23405.98798
# 7066    3096.511217
# 7067    8163.890428
# 7068    7524.442436
# 7069    2611.836866
# Name: Customer_Lifetime_Value, Length: 12074, dtype: object

# %%
data['Customer_Lifetime_Value'] = data['Customer_Lifetime_Value'].str.replace('.',',')
data['Customer_Lifetime_Value']
# Out:
# C:\Users\31645\AppData\Local\Temp/ipykernel_5336/849393747.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data['Customer_Lifetime_Value'] = data['Customer_Lifetime_Value'].str.replace('.',',')
# 0               NaN
# 1        697953,59%
# 2       1288743,17%
# 3        764586,18%
# 4        536307,65%
#            ...
# 7065            NaN
# 7066            NaN
# 7067            NaN
# 7068            NaN
# 7069            NaN
# Name: Customer_Lifetime_Value, Length: 12074, dtype: object

# %%
data
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953,59%      0.0
# 2     AI49188      Nevada      F             1288743,17%  48767.0
# 3     WW63253  California      M              764586,18%      0.0
# 4     GA49547  Washington      M              536307,65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                     NaN  71941.0
# 7066  PK87824  California      F                     NaN  21604.0
# 7067  TD14365  California      M                     NaN      0.0
# 7068  UP19263  California      M                     NaN  21941.0
# 7069  Y167826  California      M                     NaN      0.0
#
#       Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data.columns
# Out:
# Index(['Customer', 'State', 'Gender', 'Customer_Lifetime_Value', 'Income',
#        'Monthly_Premium_Auto', 'Policy_Type', 'Vehicle_Class',
#        'Total_Claim_Amount'],
#       dtype='object')

# %%
data.dtypes
# Out:
# Customer                    object
# State                       object
# Gender                      object
# Customer_Lifetime_Value     object
# Income                     float64
# Monthly_Premium_Auto       float64
# Policy_Type                 object
# Vehicle_Class               object
# Total_Claim_Amount         float64
# dtype: object

# %%
data
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953,59%      0.0
# 2     AI49188      Nevada      F             1288743,17%  48767.0
# 3     WW63253  California      M              764586,18%      0.0
# 4     GA49547  Washington      M              536307,65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                     NaN  71941.0
# 7066  PK87824  California      F                     NaN  21604.0
# 7067  TD14365  California      M                     NaN      0.0
# 7068  UP19263  California      M                     NaN  21941.0
# 7069  Y167826  California      M                     NaN      0.0
#
#       Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
dataNa = data[data['Customer_Lifetime_Value'].isna()]
dataNa
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 78    SP81997  Washington      F                     NaN  41275.0
# 988   GT62080  Washington      M                     NaN  55561.0
# 1071      NaN         NaN    NaN                     NaN      NaN
# 1072      NaN         NaN    NaN                     NaN      NaN
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                     NaN  71941.0
# 7066  PK87824  California      F                     NaN  21604.0
# 7067  TD14365  California      M                     NaN      0.0
# 7068  UP19263  California      M                     NaN  21941.0
# 7069  Y167826  California      M                     NaN      0.0
#
#       Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data['Customer_Lifetime_Value'] = data['Customer_Lifetime_Value'].fillna(0)

# %%
data
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     RB50392  Washington    NaN                       0      0.0
# 1     QZ44356     Arizona      F              697953,59%      0.0
# 2     AI49188      Nevada      F             1288743,17%  48767.0
# 3     WW63253  California      M              764586,18%      0.0
# 4     GA49547  Washington      M              536307,65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                       0  71941.0
# 7066  PK87824  California      F                       0  21604.0
# 7067  TD14365  California      M                       0      0.0
# 7068  UP19263  California      M                       0  21941.0
# 7069  Y167826  California      M                       0      0.0
#
#       Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data.dtypes
# Out:
# Customer                    object
# State                       object
# Gender                      object
# Customer_Lifetime_Value     object
# Income                     float64
# Monthly_Premium_Auto       float64
# Policy_Type                 object
# Vehicle_Class               object
# Total_Claim_Amount         float64
# dtype: object

# %%
data['Customer_Lifetime_Value'] = data['Customer_Lifetime_Value'].str.replace('%', '')
data
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F               697953,59      0.0
# 2     AI49188      Nevada      F              1288743,17  48767.0
# 3     WW63253  California      M               764586,18      0.0
# 4     GA49547  Washington      M               536307,65  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                     NaN  71941.0
# 7066  PK87824  California      F                     NaN  21604.0
# 7067  TD14365  California      M                     NaN      0.0
# 7068  UP19263  California      M                     NaN  21941.0
# 7069  Y167826  California      M                     NaN      0.0
#
#       Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data['Customer_Lifetime_Value'] = data['Customer_Lifetime_Value'].fillna(0)
data
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     RB50392  Washington    NaN                       0      0.0
# 1     QZ44356     Arizona      F               697953,59      0.0
# 2     AI49188      Nevada      F              1288743,17  48767.0
# 3     WW63253  California      M               764586,18      0.0
# 4     GA49547  Washington      M               536307,65  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                       0  71941.0
# 7066  PK87824  California      F                       0  21604.0
# 7067  TD14365  California      M                       0      0.0
# 7068  UP19263  California      M                       0  21941.0
# 7069  Y167826  California      M                       0      0.0
#
#       Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data.dtypes
# Out:
# Customer                    object
# State                       object
# Gender                      object
# Customer_Lifetime_Value     object
# Income                     float64
# Monthly_Premium_Auto       float64
# Policy_Type                 object
# Vehicle_Class               object
# Total_Claim_Amount         float64
# dtype: object

# %%
data['Customer_Lifetime_Value'] = data['Customer_Lifetime_Value'].str.replace(',', '.')
data
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F               697953.59      0.0
# 2     AI49188      Nevada      F              1288743.17  48767.0
# 3     WW63253  California      M               764586.18      0.0
# 4     GA49547  Washington      M               536307.65  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                     NaN  71941.0
# 7066  PK87824  California      F                     NaN  21604.0
# 7067  TD14365  California      M                     NaN      0.0
# 7068  UP19263  California      M                     NaN  21941.0
# 7069  Y167826  California      M                     NaN      0.0
#
#       Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data.dtypes
# Out:
# Customer                    object
# State                       object
# Gender                      object
# Customer_Lifetime_Value     object
# Income                     float64
# Monthly_Premium_Auto       float64
# Policy_Type                 object
# Vehicle_Class               object
# Total_Claim_Amount         float64
# dtype: object

# %%
data['Customer_Lifetime_Value'] = data['Customer_Lifetime_Value'].fillna(0)
data
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     RB50392  Washington    NaN                       0      0.0
# 1     QZ44356     Arizona      F               697953.59      0.0
# 2     AI49188      Nevada      F              1288743.17  48767.0
# 3     WW63253  California      M               764586.18      0.0
# 4     GA49547  Washington      M               536307.65  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                       0  71941.0
# 7066  PK87824  California      F                       0  21604.0
# 7067  TD14365  California      M                       0      0.0
# 7068  UP19263  California      M                       0  21941.0
# 7069  Y167826  California      M                       0      0.0
#
#       Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
print(data.duplicated().sum())
# Out:
# 2943

# %%
data_new = data.drop_duplicates()

# %%
data_new
# Out:
#      Customer       State Gender Customer_Lifetime_Value   Income  \
# 0     RB50392  Washington    NaN                       0      0.0
# 1     QZ44356     Arizona      F               697953.59      0.0
# 2     AI49188      Nevada      F              1288743.17  48767.0
# 3     WW63253  California      M               764586.18      0.0
# 4     GA49547  Washington      M               536307.65  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M                       0  71941.0
# 7066  PK87824  California      F                       0  21604.0
# 7067  TD14365  California      M                       0      0.0
# 7068  UP19263  California      M                       0  21941.0
# 7069  Y167826  California      M                       0      0.0
#
#       Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
data_new = data_new[data_new['Income'] <= 0]
data_new
# Out:
#      Customer       State Gender Customer_Lifetime_Value  Income  \
# 0     RB50392  Washington    NaN                       0     0.0
# 1     QZ44356     Arizona      F               697953.59     0.0
# 3     WW63253  California      M               764586.18     0.0
# 7     CF85061     Arizona      M               721610.03     0.0
# 10    SX51350  California      M               473899.20     0.0
# ...       ...         ...    ...                     ...     ...
# 7059  WZ45103  California      F                       0     0.0
# 7061  RX91025  California      M                       0     0.0
# 7062  AC13887  California      M                       0     0.0
# 7067  TD14365  California      M                       0     0.0
# 7069  Y167826  California      M                       0     0.0
#
#       Monthly_Premium_Auto     Policy_Type  Vehicle_Class  Total_Claim_Amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...
